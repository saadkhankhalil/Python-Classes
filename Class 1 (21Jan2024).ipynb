# %% [markdown]
# # Programming fundimental with python

# %% [markdown]
# # # Todays topics
# .pint()
# .data
# .type

# %% [markdown]
# to run a code press shift+enter>> cell execute, new cell add below cntrl+enter

# %%
print("Helle Saad")
# Out:
# Helle Saad

# %% [markdown]
# Values: Data
#     text:String:str:"Hello":'Hello':'''Hello''':"""Hello"""
#   Numbers:
#     -Whole: Integers:int:434888
#                 -Decimal:Float:2.2
#                 -Boolean:ON\OFF: True\False
#                         -

# %% [markdown]
# # Python:
# .Case sensitive language
# .interpreter base language
# .Open source
# .Mobie Apps
# .Web Apps
# .Data Science
# .Robotics
# .Machine learning

# %%
print("saad","ali","umer", sep="")
# Out:
# saadaliumer

# %%
print("hy i am saad \n i am from peshawar")
# Out:
# hy i am saad
#  i am from peshawar

# %%
print("saad",end="")
print("ali",end="")
# Out:
# saadali

# %%
print("my name is saad khan khalil \' and i am from peshawar")
# Out:
# my name is saad khan khalil ' and i am from peshawar

# %%
print("my name is saad khan khalil \\ and i am from peshawar")
# Out:
# my name is saad khan khalil \ and i am from peshawar

# %%
print("my name is saad khan khalil \n and i am from peshawar")
# Out:
# my name is saad khan khalil
#  and i am from peshawar

# %%
print("my name is saad khan khalil \b and i am from peshawar")
# Out:
#  and i am from peshawar

# %%
print("my name is saad khan khalil \f and i am from peshawar")
# Out:
# my name is saad khan khalil  and i am from peshawar

# %%
print("my name is saad khan khalil \r and i am from peshawar")
# Out:
#  and i am from peshawar

# %%
txt = "hello \bworld"
print(txt)
# Out:
# world

# %%
txt = "hello\rworld!"
print(txt)
# Out:
# world!

# %%
txt = "\x42\x99\x67\x6c\x6f"
print(txt)
# Out:
# Bglo

# %%
import numpy
speed = [27,33,334,55,66,77,88,10]
x=numpy.mean(speed)
print(x)
# Out:
# 86.25

# %%
from scipy import stats
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
x=stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=86, count=3)

# %%
import numpy
speed = [12,22,33,44,55,66,77,88,99]
x=numpy.median(speed)
print(x)
# Out:
# 55.0

# %%
from scipy import stats
speed = [21,22,11,22,33,22,22,33,443,44,33,33,22,222,222,22,22,22,22,22,22,22,22,22]
x=stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=22, count=14)

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([4,5,3,5,6,2])
ypoints = np.array ([2.3,5,2,4,5,2])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,3,4,5,6])
ypoints = np.array ([7,8,9,10,11,12])
plt.plot(xpoints,ypoints)
plt.show()
